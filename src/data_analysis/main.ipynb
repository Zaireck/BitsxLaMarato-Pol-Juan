# %%
#!pip install pandas
#!pip install numpy
#!pip install matplotlib
#!pip install seaborn
#!pip install scikit-learn
#!pip install torch
#!pip install flask

# %%
import pandas as pd

# %%
relevant_cols = [
    "edad",
    "imc",
    "f_diag",
    "tipo_histologico",
    "Grado",
    "valor_de_ca125",
    "ecotv_infiltobj",
    "ecotv_infiltsub",
    "metasta_distan",
    "estadiaje_pre_i",
    "grupo_riesgo",
    "tto_NA",
    "fecha_qx",
    "asa",
    "histo_defin",
    "grado_histologi",
    "tamano_tumoral",
    "afectacion_linf",
    "AP_centinela_pelvico",
    "AP_ganPelv",
    "AP_glanPaor",
    "recep_est_porcent",
    "rece_de_Ppor",
    "beta_cateninap",
    "estudio_genetico_r01",
    "estudio_genetico_r02",
    "estudio_genetico_r03",
    "estudio_genetico_r04",
    "estudio_genetico_r05",
    "estudio_genetico_r06",
    "estadificacion_",
    "FIGO2023",
    "grupo_de_riesgo_definitivo",
    "bqt",
    "qt",
    "Tributaria_a_Radioterapia",
    "Tratamiento_RT",
    "Tratamiento_sistemico",
    "visita_control",
    "recidiva",
    "est_pcte",
    "causa_muerte",
    "f_muerte",
    "libre_enferm",
    "numero_de_recid",
    "fecha_de_recidi",
    "dx_recidiva",
    "rdt",
    "num_recidiva",
    "tto_recidiva",
    "Tt_recidiva_qx",
    "Reseccion_macroscopica_complet"
]

# %%
data = pd.read_csv("../data_source/IQ_Cancer_Endometrio_merged_NMS.csv")
data_relevant = data[relevant_cols]
data_relevant.head()
# Out:
#    edad    imc      f_diag  tipo_histologico  Grado  valor_de_ca125  \
# 0  68.0  39.40  2023-11-03                 2      2           283.0
# 1  92.0  24.14  2019-10-24                 1      1             NaN
# 2  72.0  38.80  2020-07-16                 2      1             NaN
# 3  78.0  36.30  2021-02-22                 2      1             NaN
# 4  68.0  31.10  2019-11-15                 2      1             NaN
#
#    ecotv_infiltobj  ecotv_infiltsub  metasta_distan  estadiaje_pre_i  ...  \
# 0              4.0              2.0             1.0              2.0  ...
# 1              3.0              4.0             0.0              NaN  ...
# 2              3.0              4.0             0.0              0.0  ...
# 3              3.0              3.0             0.0              1.0  ...
# 4              NaN              3.0             0.0              0.0  ...
#
#      f_muerte  libre_enferm numero_de_recid  fecha_de_recidi  dx_recidiva  \
# 0         NaN             0             0.0              NaN          NaN
# 1  08/04/2021             0             NaN              NaN          NaN
# 2         NaN             1             NaN              NaN          NaN
# 3         NaN             1             1.0       22/11/2023          1.0
# 4         NaN             1             NaN              NaN          NaN
#
#    rdt  num_recidiva  tto_recidiva  Tt_recidiva_qx  \
# 0  NaN           NaN           NaN             NaN
# 1  NaN           NaN           NaN             NaN
# 2  NaN           NaN           NaN             NaN
# 3  2.0           1.0           1.0             0.0
# 4  NaN           NaN           NaN             NaN
#
#    Reseccion_macroscopica_complet
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 52 columns]

# %%
data_relevant.describe().T
# Out:
#                                 count        mean         std   min    25%  \
# edad                            163.0   62.190184   14.524374   0.0  54.00
# imc                             155.0   30.726258    7.738904  16.7  24.40
# tipo_histologico                163.0    4.171779   11.696045   1.0   2.00
# Grado                           163.0    1.190184    0.393656   1.0   1.00
# valor_de_ca125                   21.0  148.671429  324.352458   3.7  19.30
# ecotv_infiltobj                 157.0    3.331210    1.064512   1.0   3.00
# ecotv_infiltsub                 162.0    2.629630    0.848007   1.0   2.00
# metasta_distan                  159.0    0.056604    0.231814   0.0   0.00
# estadiaje_pre_i                 160.0    0.368750    0.732205   0.0   0.00
# grupo_riesgo                    161.0    1.515528    0.725479   1.0   1.00
# tto_NA                          163.0    0.018405    0.134825   0.0   0.00
# asa                             144.0    1.194444    0.532546   0.0   1.00
# histo_defin                     151.0    2.827815    2.128416   1.0   2.00
# grado_histologi                 145.0    1.206897    0.406485   1.0   1.00
# tamano_tumoral                  132.0    3.829924    4.551802   0.0   1.75
# afectacion_linf                 144.0    0.208333    0.407534   0.0   0.00
# AP_centinela_pelvico            132.0    2.810606    1.808093   0.0   0.00
# AP_ganPelv                       55.0    0.563636    1.166883   0.0   0.00
# AP_glanPaor                      32.0    0.656250    1.207754   0.0   0.00
# recep_est_porcent                91.0   76.329670   27.057574   0.0  70.00
# rece_de_Ppor                     89.0   69.528090   30.671311   0.0  60.00
# beta_cateninap                  151.0    0.860927    0.902144   0.0   0.00
# estudio_genetico_r01            154.0    0.045455    0.208979   0.0   0.00
# estudio_genetico_r02            154.0    0.006494    0.080582   0.0   0.00
# estudio_genetico_r03            154.0    0.006494    0.080582   0.0   0.00
# estudio_genetico_r04            154.0    0.006494    0.080582   0.0   0.00
# estudio_genetico_r05            154.0    0.019481    0.138657   0.0   0.00
# estudio_genetico_r06            154.0    0.935065    0.247215   0.0   1.00
# estadificacion_                 139.0    2.467626    2.488531   1.0   1.00
# FIGO2023                        142.0    3.704225    4.073420   1.0   1.00
# grupo_de_riesgo_definitivo      143.0    1.965035    1.396235   1.0   1.00
# bqt                             154.0    0.279221    0.450080   0.0   0.00
# qt                              153.0    0.209150    0.408038   0.0   0.00
# Tributaria_a_Radioterapia       155.0    0.232258    0.423642   0.0   0.00
# Tratamiento_RT                   28.0    0.285714    0.460044   0.0   0.00
# Tratamiento_sistemico            29.0    0.517241    0.508548   0.0   0.00
# recidiva                        163.0    0.288344    0.563542   0.0   0.00
# est_pcte                        163.0    1.226994    0.488138   1.0   1.00
# causa_muerte                     27.0    0.518519    0.509175   0.0   0.00
# libre_enferm                    163.0    0.920245    0.577153   0.0   1.00
# numero_de_recid                  30.0    1.133333    0.434172   0.0   1.00
# dx_recidiva                      29.0    0.896552    0.309934   0.0   1.00
# rdt                              33.0    1.030303    0.529437   0.0   1.00
# num_recidiva                      8.0    1.750000    0.462910   1.0   1.75
# tto_recidiva                     29.0    1.482759    0.633623   0.0   1.00
# Tt_recidiva_qx                   29.0    0.551724    0.572351   0.0   0.00
# Reseccion_macroscopica_complet   27.0    0.481481    0.509175   0.0   0.00
#
#                                  50%    75%     max
# edad                            63.0  72.00    92.0
# imc                             29.4  35.30    56.1
# tipo_histologico                 2.0   2.00    88.0
# Grado                            1.0   1.00     2.0
# valor_de_ca125                  30.1  93.80  1486.9
# ecotv_infiltobj                  4.0   4.00     4.0
# ecotv_infiltsub                  2.5   3.00     4.0
# metasta_distan                   0.0   0.00     1.0
# estadiaje_pre_i                  0.0   0.00     2.0
# grupo_riesgo                     1.0   2.00     3.0
# tto_NA                           0.0   0.00     1.0
# asa                              1.0   2.00     2.0
# histo_defin                      2.0   2.00     9.0
# grado_histologi                  1.0   1.00     2.0
# tamano_tumoral                   3.0   4.00    38.0
# afectacion_linf                  0.0   0.00     1.0
# AP_centinela_pelvico             4.0   4.00     4.0
# AP_ganPelv                       0.0   0.00     3.0
# AP_glanPaor                      0.0   0.25     3.0
# recep_est_porcent               90.0  90.00   100.0
# rece_de_Ppor                    80.0  90.00   100.0
# beta_cateninap                   1.0   2.00     2.0
# estudio_genetico_r01             0.0   0.00     1.0
# estudio_genetico_r02             0.0   0.00     1.0
# estudio_genetico_r03             0.0   0.00     1.0
# estudio_genetico_r04             0.0   0.00     1.0
# estudio_genetico_r05             0.0   0.00     1.0
# estudio_genetico_r06             1.0   1.00     1.0
# estadificacion_                  1.0   2.50     9.0
# FIGO2023                         1.0   4.00    14.0
# grupo_de_riesgo_definitivo       1.0   3.00     5.0
# bqt                              0.0   1.00     1.0
# qt                               0.0   0.00     1.0
# Tributaria_a_Radioterapia        0.0   0.00     1.0
# Tratamiento_RT                   0.0   1.00     1.0
# Tratamiento_sistemico            1.0   1.00     1.0
# recidiva                         0.0   0.00     2.0
# est_pcte                         1.0   1.00     3.0
# causa_muerte                     1.0   1.00     1.0
# libre_enferm                     1.0   1.00     2.0
# numero_de_recid                  1.0   1.00     2.0
# dx_recidiva                      1.0   1.00     1.0
# rdt                              1.0   1.00     2.0
# num_recidiva                     2.0   2.00     2.0
# tto_recidiva                     2.0   2.00     2.0
# Tt_recidiva_qx                   1.0   1.00     2.0
# Reseccion_macroscopica_complet   0.0   1.00     1.0

# %%
data_relevant.isnull().sum()
# Out:
# edad                                0
# imc                                 8
# f_diag                              2
# tipo_histologico                    0
# Grado                               0
# valor_de_ca125                    142
# ecotv_infiltobj                     6
# ecotv_infiltsub                     1
# metasta_distan                      4
# estadiaje_pre_i                     3
# grupo_riesgo                        2
# tto_NA                              0
# fecha_qx                           12
# asa                                19
# histo_defin                        12
# grado_histologi                    18
# tamano_tumoral                     31
# afectacion_linf                    19
# AP_centinela_pelvico               31
# AP_ganPelv                        108
# AP_glanPaor                       131
# recep_est_porcent                  72
# rece_de_Ppor                       74
# beta_cateninap                     12
# estudio_genetico_r01                9
# estudio_genetico_r02                9
# estudio_genetico_r03                9
# estudio_genetico_r04                9
# estudio_genetico_r05                9
# estudio_genetico_r06                9
# estadificacion_                    24
# FIGO2023                           21
# grupo_de_riesgo_definitivo         20
# bqt                                 9
# qt                                 10
# Tributaria_a_Radioterapia           8
# Tratamiento_RT                    135
# Tratamiento_sistemico             134
# visita_control                      0
# recidiva                            0
# est_pcte                            0
# causa_muerte                      136
# f_muerte                          136
# libre_enferm                        0
# numero_de_recid                   133
# fecha_de_recidi                   134
# dx_recidiva                       134
# rdt                               130
# num_recidiva                      155
# tto_recidiva                      134
# Tt_recidiva_qx                    134
# Reseccion_macroscopica_complet    136
# dtype: int64
